# %% [markdown]
# # NN Training

# %%
# First, train the keras models
from train_keras import train as ktrain


# Keras model has very bad train accuracy but good test accuracy. Maybe Dropout is too aggressive?
ktrain(nepochs=10, plot_history=True)
# Out:
# Using TensorFlow backend.
# Model: "KerasEggNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 784, 1)            0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 784, 1)            4
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        144
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 16)        64
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 28, 28, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 28, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 32)        4608
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                50208
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 32)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 55,486
# Trainable params: 55,388
# Non-trainable params: 98
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/10
# 54000/54000 [==============================] - 25s 456us/step - loss: 1.4608 - accuracy: 0.4396 - val_loss: 0.6901 - val_accuracy: 0.9470
#
# Epoch 00001: saving model to keras/cp.ckpt
# Epoch 2/10
# 54000/54000 [==============================] - 25s 460us/step - loss: 1.1580 - accuracy: 0.5375 - val_loss: 0.3951 - val_accuracy: 0.9715
#
# Epoch 00002: saving model to keras/cp.ckpt
# Epoch 3/10
# 54000/54000 [==============================] - 26s 477us/step - loss: 0.9167 - accuracy: 0.6688 - val_loss: 0.2938 - val_accuracy: 0.9780
#
# Epoch 00003: saving model to keras/cp.ckpt
# Epoch 4/10
# 54000/54000 [==============================] - 25s 463us/step - loss: 0.7473 - accuracy: 0.7278 - val_loss: 0.1261 - val_accuracy: 0.9858
#
# Epoch 00004: saving model to keras/cp.ckpt
# Epoch 5/10
# 54000/54000 [==============================] - 25s 455us/step - loss: 0.6502 - accuracy: 0.7611 - val_loss: 0.1352 - val_accuracy: 0.9858
#
# Epoch 00005: saving model to keras/cp.ckpt
# Epoch 6/10
# 54000/54000 [==============================] - 26s 484us/step - loss: 0.6392 - accuracy: 0.7625 - val_loss: 0.1182 - val_accuracy: 0.9890
#
# Epoch 00006: saving model to keras/cp.ckpt
# Epoch 7/10
# 54000/54000 [==============================] - 28s 513us/step - loss: 0.6233 - accuracy: 0.7678 - val_loss: 0.1123 - val_accuracy: 0.9845
#
# Epoch 00007: saving model to keras/cp.ckpt
# Epoch 8/10
# 54000/54000 [==============================] - 27s 491us/step - loss: 0.5642 - accuracy: 0.7910 - val_loss: 0.1277 - val_accuracy: 0.9850
#
# Epoch 00008: saving model to keras/cp.ckpt
# Epoch 9/10
# 54000/54000 [==============================] - 24s 451us/step - loss: 0.5485 - accuracy: 0.8004 - val_loss: 0.1241 - val_accuracy: 0.9835
#
# Epoch 00009: saving model to keras/cp.ckpt
# Epoch 10/10
# 54000/54000 [==============================] - 24s 446us/step - loss: 0.5311 - accuracy: 0.8068 - val_loss: 0.0978 - val_accuracy: 0.9888
#
# Epoch 00010: saving model to keras/cp.ckpt

# %%
from train_torch import train as ttrain

ttrain(nepochs=10, plot_history=True)
# Out:
# Epoch:   0   MB:    49   Acc [%]  30.0 %
# Epoch:   0   MB:    99   Acc [%]  54.0 %
# Epoch:   0   MB:   149   Acc [%]  48.0 %
# Epoch:   0   MB:   199   Acc [%]  68.0 %
# Epoch:   0   MB:   249   Acc [%]  64.0 %
# Epoch:   0   MB:   299   Acc [%]  68.0 %
# Epoch:   0   MB:   349   Acc [%]  68.0 %
# Epoch:   0   MB:   399   Acc [%]  74.0 %
# Epoch:   0   MB:   449   Acc [%]  80.0 %
# Epoch:   0   MB:   499   Acc [%]  74.0 %
# Epoch:   0   MB:   549   Acc [%]  82.0 %
# Epoch:   0   MB:   599   Acc [%]  76.0 %
# Epoch:   0   MB:   649   Acc [%]  76.0 %
# Epoch:   0   MB:   699   Acc [%]  74.0 %
# Epoch:   0   MB:   749   Acc [%]  82.0 %
# Epoch:   0   MB:   799   Acc [%]  72.0 %
# Epoch:   0   MB:   849   Acc [%]  74.0 %
# Epoch:   0   MB:   899   Acc [%]  88.0 %
# Epoch:   0   MB:   949   Acc [%]  74.0 %
# Epoch:   0   MB:   999   Acc [%]  94.0 %
# Epoch:   0   MB:  1049   Acc [%]  80.0 %
# Epoch:   0   MB:  1099   Acc [%]  88.0 %
# Epoch:   0   MB:  1149   Acc [%]  94.0 %
# Epoch:   0   MB:  1199   Acc [%]  78.0 %
# Epoch:   1   MB:    49   Acc [%]  76.0 %
# Epoch:   1   MB:    99   Acc [%]  80.0 %
# Epoch:   1   MB:   149   Acc [%]  82.0 %
# Epoch:   1   MB:   199   Acc [%]  82.0 %
# Epoch:   1   MB:   249   Acc [%]  74.0 %
# Epoch:   1   MB:   299   Acc [%]  82.0 %
# Epoch:   1   MB:   349   Acc [%]  84.0 %
# Epoch:   1   MB:   399   Acc [%]  96.0 %
# Epoch:   1   MB:   449   Acc [%]  92.0 %
# Epoch:   1   MB:   499   Acc [%]  80.0 %
# Epoch:   1   MB:   549   Acc [%]  86.0 %
# Epoch:   1   MB:   599   Acc [%]  96.0 %
# Epoch:   1   MB:   649   Acc [%]  82.0 %
# Epoch:   1   MB:   699   Acc [%]  92.0 %
# Epoch:   1   MB:   749   Acc [%]  86.0 %
# Epoch:   1   MB:   799   Acc [%]  88.0 %
# Epoch:   1   MB:   849   Acc [%]  92.0 %
# Epoch:   1   MB:   899   Acc [%]  90.0 %
# Epoch:   1   MB:   949   Acc [%]  88.0 %
# Epoch:   1   MB:   999   Acc [%]  90.0 %
# Epoch:   1   MB:  1049   Acc [%]  86.0 %
# Epoch:   1   MB:  1099   Acc [%]  84.0 %
# Epoch:   1   MB:  1149   Acc [%]  88.0 %
# Epoch:   1   MB:  1199   Acc [%]  80.0 %
# Epoch:   2   MB:    49   Acc [%]  74.0 %
# Epoch:   2   MB:    99   Acc [%]  88.0 %
# Epoch:   2   MB:   149   Acc [%]  84.0 %
# Epoch:   2   MB:   199   Acc [%]  92.0 %
# Epoch:   2   MB:   249   Acc [%]  88.0 %
# Epoch:   2   MB:   299   Acc [%]  86.0 %
# Epoch:   2   MB:   349   Acc [%]  88.0 %
# Epoch:   2   MB:   399   Acc [%]  92.0 %
# Epoch:   2   MB:   449   Acc [%]  92.0 %
# Epoch:   2   MB:   499   Acc [%]  92.0 %
# Epoch:   2   MB:   549   Acc [%]  92.0 %
# Epoch:   2   MB:   599   Acc [%]  86.0 %
# Epoch:   2   MB:   649   Acc [%]  82.0 %
# Epoch:   2   MB:   699   Acc [%]  94.0 %
# Epoch:   2   MB:   749   Acc [%]  90.0 %
# Epoch:   2   MB:   799   Acc [%]  82.0 %
# Epoch:   2   MB:   849   Acc [%]  88.0 %
# Epoch:   2   MB:   899   Acc [%]  88.0 %
# Epoch:   2   MB:   949   Acc [%]  92.0 %
# Epoch:   2   MB:   999   Acc [%]  88.0 %
# Epoch:   2   MB:  1049   Acc [%]  80.0 %
# Epoch:   2   MB:  1099   Acc [%]  84.0 %
# Epoch:   2   MB:  1149   Acc [%]  94.0 %
# Epoch:   2   MB:  1199   Acc [%]  80.0 %
# Epoch:   3   MB:    49   Acc [%]  92.0 %
# Epoch:   3   MB:    99   Acc [%]  90.0 %
# Epoch:   3   MB:   149   Acc [%]  86.0 %
# Epoch:   3   MB:   199   Acc [%]  94.0 %
# Epoch:   3   MB:   249   Acc [%]  86.0 %
# Epoch:   3   MB:   299   Acc [%]  88.0 %
# Epoch:   3   MB:   349   Acc [%]  78.0 %
# Epoch:   3   MB:   399   Acc [%]  92.0 %
# Epoch:   3   MB:   449   Acc [%]  88.0 %
# Epoch:   3   MB:   499   Acc [%]  84.0 %
# Epoch:   3   MB:   549   Acc [%]  78.0 %
# Epoch:   3   MB:   599   Acc [%]  92.0 %
# Epoch:   3   MB:   649   Acc [%]  80.0 %
# Epoch:   3   MB:   699   Acc [%]  80.0 %
# Epoch:   3   MB:   749   Acc [%]  94.0 %
# Epoch:   3   MB:   799   Acc [%]  88.0 %
# Epoch:   3   MB:   849   Acc [%]  92.0 %
# Epoch:   3   MB:   899   Acc [%]  84.0 %
# Epoch:   3   MB:   949   Acc [%]  94.0 %
# Epoch:   3   MB:   999   Acc [%]  88.0 %
# Epoch:   3   MB:  1049   Acc [%]  88.0 %
# Epoch:   3   MB:  1099   Acc [%]  94.0 %
# Epoch:   3   MB:  1149   Acc [%]  94.0 %
# Epoch:   3   MB:  1199   Acc [%]  94.0 %
# Epoch:   4   MB:    49   Acc [%]  92.0 %
# Epoch:   4   MB:    99   Acc [%]  88.0 %
# Epoch:   4   MB:   149   Acc [%]  90.0 %
# Epoch:   4   MB:   199   Acc [%]  90.0 %
# Epoch:   4   MB:   249   Acc [%]  94.0 %
# Epoch:   4   MB:   299   Acc [%]  92.0 %
# Epoch:   4   MB:   349   Acc [%]  92.0 %
# Epoch:   4   MB:   399   Acc [%]  94.0 %
# Epoch:   4   MB:   449   Acc [%]  90.0 %
# Epoch:   4   MB:   499   Acc [%]  90.0 %
# Epoch:   4   MB:   549   Acc [%]  88.0 %
# Epoch:   4   MB:   599   Acc [%]  90.0 %
# Epoch:   4   MB:   649   Acc [%]  90.0 %
# Epoch:   4   MB:   699   Acc [%]  84.0 %
# Epoch:   4   MB:   749   Acc [%]  92.0 %
# Epoch:   4   MB:   799   Acc [%]  84.0 %
# Epoch:   4   MB:   849   Acc [%]  86.0 %
# Epoch:   4   MB:   899   Acc [%]  86.0 %
# Epoch:   4   MB:   949   Acc [%]  94.0 %
# Epoch:   4   MB:   999   Acc [%]  90.0 %
# Epoch:   4   MB:  1049   Acc [%]  92.0 %
# Epoch:   4   MB:  1099   Acc [%]  86.0 %
# Epoch:   4   MB:  1149   Acc [%]  90.0 %
# Epoch:   4   MB:  1199   Acc [%]  90.0 %
# Epoch:   5   MB:    49   Acc [%]  86.0 %
# Epoch:   5   MB:    99   Acc [%]  98.0 %
# Epoch:   5   MB:   149   Acc [%]  96.0 %
# Epoch:   5   MB:   199   Acc [%]  88.0 %
# Epoch:   5   MB:   249   Acc [%]  88.0 %
# Epoch:   5   MB:   299   Acc [%]  86.0 %
# Epoch:   5   MB:   349   Acc [%]  86.0 %
# Epoch:   5   MB:   399   Acc [%]  94.0 %
# Epoch:   5   MB:   449   Acc [%]  90.0 %
# Epoch:   5   MB:   499   Acc [%]  94.0 %
# Epoch:   5   MB:   549   Acc [%]  90.0 %
# Epoch:   5   MB:   599   Acc [%]  98.0 %
# Epoch:   5   MB:   649   Acc [%]  96.0 %
# Epoch:   5   MB:   699   Acc [%]  96.0 %
# Epoch:   5   MB:   749   Acc [%]  90.0 %
# Epoch:   5   MB:   799   Acc [%]  94.0 %
# Epoch:   5   MB:   849   Acc [%]  88.0 %
# Epoch:   5   MB:   899   Acc [%]  90.0 %
# Epoch:   5   MB:   949   Acc [%]  86.0 %
# Epoch:   5   MB:   999   Acc [%]  94.0 %
# Epoch:   5   MB:  1049   Acc [%]  98.0 %
# Epoch:   5   MB:  1099   Acc [%]  94.0 %
# Epoch:   5   MB:  1149   Acc [%]  94.0 %
# Epoch:   5   MB:  1199   Acc [%]  92.0 %
# Epoch:   6   MB:    49   Acc [%]  98.0 %
# Epoch:   6   MB:    99   Acc [%]  90.0 %
# Epoch:   6   MB:   149   Acc [%]  90.0 %
# Epoch:   6   MB:   199   Acc [%]  86.0 %
# Epoch:   6   MB:   249   Acc [%]  92.0 %
# Epoch:   6   MB:   299   Acc [%]  94.0 %
# Epoch:   6   MB:   349   Acc [%]  90.0 %
# Epoch:   6   MB:   399   Acc [%]  96.0 %
# Epoch:   6   MB:   449   Acc [%]  96.0 %
# Epoch:   6   MB:   499   Acc [%]  92.0 %
# Epoch:   6   MB:   549   Acc [%]  88.0 %
# Epoch:   6   MB:   599   Acc [%]  88.0 %
# Epoch:   6   MB:   649   Acc [%]  96.0 %
# Epoch:   6   MB:   699   Acc [%]  96.0 %
# Epoch:   6   MB:   749   Acc [%]  90.0 %
# Epoch:   6   MB:   799   Acc [%]  96.0 %
# Epoch:   6   MB:   849   Acc [%]  100.0 %
# Epoch:   6   MB:   899   Acc [%]  88.0 %
# Epoch:   6   MB:   949   Acc [%]  90.0 %
# Epoch:   6   MB:   999   Acc [%]  94.0 %
# Epoch:   6   MB:  1049   Acc [%]  86.0 %
# Epoch:   6   MB:  1099   Acc [%]  84.0 %
# Epoch:   6   MB:  1149   Acc [%]  96.0 %
# Epoch:   6   MB:  1199   Acc [%]  92.0 %
# Epoch:   7   MB:    49   Acc [%]  86.0 %
# Epoch:   7   MB:    99   Acc [%]  90.0 %
# Epoch:   7   MB:   149   Acc [%]  90.0 %
# Epoch:   7   MB:   199   Acc [%]  98.0 %
# Epoch:   7   MB:   249   Acc [%]  92.0 %
# Epoch:   7   MB:   299   Acc [%]  92.0 %
# Epoch:   7   MB:   349   Acc [%]  94.0 %
# Epoch:   7   MB:   399   Acc [%]  96.0 %
# Epoch:   7   MB:   449   Acc [%]  94.0 %
# Epoch:   7   MB:   499   Acc [%]  94.0 %
# Epoch:   7   MB:   549   Acc [%]  100.0 %
# Epoch:   7   MB:   599   Acc [%]  90.0 %
# Epoch:   7   MB:   649   Acc [%]  92.0 %
# Epoch:   7   MB:   699   Acc [%]  92.0 %
# Epoch:   7   MB:   749   Acc [%]  92.0 %
# Epoch:   7   MB:   799   Acc [%]  86.0 %
# Epoch:   7   MB:   849   Acc [%]  96.0 %
# Epoch:   7   MB:   899   Acc [%]  86.0 %
# Epoch:   7   MB:   949   Acc [%]  90.0 %
# Epoch:   7   MB:   999   Acc [%]  94.0 %
# Epoch:   7   MB:  1049   Acc [%]  92.0 %
# Epoch:   7   MB:  1099   Acc [%]  96.0 %
# Epoch:   7   MB:  1149   Acc [%]  92.0 %
# Epoch:   7   MB:  1199   Acc [%]  94.0 %
# Epoch:   8   MB:    49   Acc [%]  94.0 %
# Epoch:   8   MB:    99   Acc [%]  92.0 %
# Epoch:   8   MB:   149   Acc [%]  92.0 %
# Epoch:   8   MB:   199   Acc [%]  94.0 %
# Epoch:   8   MB:   249   Acc [%]  92.0 %
# Epoch:   8   MB:   299   Acc [%]  96.0 %
# Epoch:   8   MB:   349   Acc [%]  98.0 %
# Epoch:   8   MB:   399   Acc [%]  90.0 %
# Epoch:   8   MB:   449   Acc [%]  96.0 %
# Epoch:   8   MB:   499   Acc [%]  94.0 %
# Epoch:   8   MB:   549   Acc [%]  90.0 %
# Epoch:   8   MB:   599   Acc [%]  96.0 %
# Epoch:   8   MB:   649   Acc [%]  94.0 %
# Epoch:   8   MB:   699   Acc [%]  92.0 %
# Epoch:   8   MB:   749   Acc [%]  94.0 %
# Epoch:   8   MB:   799   Acc [%]  98.0 %
# Epoch:   8   MB:   849   Acc [%]  96.0 %
# Epoch:   8   MB:   899   Acc [%]  96.0 %
# Epoch:   8   MB:   949   Acc [%]  90.0 %
# Epoch:   8   MB:   999   Acc [%]  94.0 %
# Epoch:   8   MB:  1049   Acc [%]  96.0 %
# Epoch:   8   MB:  1099   Acc [%]  94.0 %
# Epoch:   8   MB:  1149   Acc [%]  84.0 %
# Epoch:   8   MB:  1199   Acc [%]  90.0 %
# Epoch:   9   MB:    49   Acc [%]  94.0 %
# Epoch:   9   MB:    99   Acc [%]  96.0 %
# Epoch:   9   MB:   149   Acc [%]  92.0 %
# Epoch:   9   MB:   199   Acc [%]  96.0 %
# Epoch:   9   MB:   249   Acc [%]  98.0 %
# Epoch:   9   MB:   299   Acc [%]  88.0 %
# Epoch:   9   MB:   349   Acc [%]  96.0 %
# Epoch:   9   MB:   399   Acc [%]  94.0 %
# Epoch:   9   MB:   449   Acc [%]  92.0 %
# Epoch:   9   MB:   499   Acc [%]  90.0 %
# Epoch:   9   MB:   549   Acc [%]  88.0 %
# Epoch:   9   MB:   599   Acc [%]  94.0 %
# Epoch:   9   MB:   649   Acc [%]  92.0 %
# Epoch:   9   MB:   699   Acc [%]  94.0 %
# Epoch:   9   MB:   749   Acc [%]  94.0 %
# Epoch:   9   MB:   799   Acc [%]  98.0 %
# Epoch:   9   MB:   849   Acc [%]  86.0 %
# Epoch:   9   MB:   899   Acc [%]  96.0 %
# Epoch:   9   MB:   949   Acc [%]  90.0 %
# Epoch:   9   MB:   999   Acc [%]  100.0 %
# Epoch:   9   MB:  1049   Acc [%]  92.0 %
# Epoch:   9   MB:  1099   Acc [%]  92.0 %
# Epoch:   9   MB:  1149   Acc [%]  98.0 %
# Epoch:   9   MB:  1199   Acc [%]  92.0 %
# Finished Training
# Test accuracy: 98.59%

# %% [markdown]
# ## Save Network weights aka convert them to numpy text files

# %%
from extract_net_parameters import extract
extract(cleanup=True, extract_keras=True, extract_torch=True)
