# %% [markdown]
# # NN Training

# %%
# First, train the keras models
from train_keras import train as ktrain


# Keras model has very bad train accuracy but good test accuracy. Maybe Dropout is too aggressive?
model = ktrain(nepochs=10, plot_history=True)
# Out:
# Using TensorFlow backend.
# Model: "KerasEggNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# reshape_1 (Reshape)          (None, 784, 1)            0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 784, 1)            4
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 4)         100
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 4)         16
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 28, 4)         0
# _________________________________________________________________
# ...

# %%
from train_torch import train as ttrain

ttrain(nepochs=10, plot_history=True)
# Out:
# ...
# 40.2%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ed095ee6927b> in <module>
#       2 from train_torch import train as ttrain
#       3
# ----> 4 ttrain(nepochs=10, plot_history=True)
#       5
#
# ~/Developer/FPGA_MNIST/net/train_torch.py in train(nepochs, plot_history)
#      60
#      61     # data sets & data loaders
# ---> 62     trainset = torchvision.datasets.MNIST('./data', download=True, train=True, transform=transforms)
#      63     testset = torchvision.datasets.MNIST('./data', download=True, train=False, transform=transforms)
#      64     trainloader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
#
# ~/Developer/FPGA_MNIST/venv/lib/python3.7/site-packages/torchvision/datasets/mnist.py in __init__(self, root, train, transform, target_transform, download)
#      68
#      69         if download:
# ...

# %% [markdown]
# ## Save Network weights aka convert them to numpy text files

# %%
from extract_net_parameters import extract
extract(cleanup=True, extract_keras=True, extract_torch=True)
